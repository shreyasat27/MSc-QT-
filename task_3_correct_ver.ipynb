# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyasat27/MSc-QT-/blob/main/task_3_correct_ver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qutip
# Out:
# Collecting qutip
#   Downloading qutip-5.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from qutip) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from qutip) (1.13.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qutip) (24.2)
# Downloading qutip-5.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 26.0 MB/s eta 0:00:00
# Installing collected packages: qutip
# Successfully installed qutip-5.1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 0.1 * 2 * np.pi         # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)

# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/qutip/solver/solver_base.py:576: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 0.1 * 2 * np.pi         # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = np.pi/2         # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/qutip/solver/solver_base.py:576: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 0.1 * 2 * np.pi         # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = np.pi/3          # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/qutip/solver/solver_base.py:576: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 1    # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 35      # Coupling strength
N = 15 #try it out with diff no.                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 25, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 36        # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 0.5       # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


# Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

# Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=2*np.sqrt(((epsilon/2)**2)+t_c**2) #choose a value

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = [ ]

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()

# %% [markdown]
# Qubit frequency --> 2Ω
#
# Ω_R=2*Ω

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega =  2 * np.pi
g = 0.1 * 2 * np.pi      # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 15, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


#Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

#Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

#Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R=1*omega

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = []

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters

omega = 1* np.pi
g = 0.2     # Coupling strength
N = 3                      # Number of Fock states in the cavity
theta = 0            # Angle determining the qubit orientation
kappa = 0.00005             # Cavity dissipation rate
gamma = 0.0005              # Qubit relaxation rate
tlist = np.linspace(0, 25, 100)  # Time array for simulation
epsilon=2*omega *np.sin(theta) # Energy detuning of the qubit (in angular frequency units)
t_c = 1* omega *np.cos(theta)     # Tunnel coupling between qubit states (in angular frequency units)


#Initial state
psi0 = tensor(basis(N, 1), (basis(2, 0))) #basis(2,1)).unit())    # Qubit in excited state

#Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), Qobj([[1, 0], [0, 1]])) #identity

#Hamiltonian
H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)

omega_R= 2*2*np.pi

H_res = omega_R * a.dag()*a
H = H_matrix + H_interaction + H_res
# Collapse operators (dissipation)
c_ops = []

# Solve the master equation
output = mesolve(H, psi0, tlist, c_ops, [a.dag() * a,((-sigma_z+idn)/2)])

# Plot the results
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(tlist, output.expect[0], label="Cavity photon number")
ax.plot(tlist, output.expect[1], label="Qubit excitation probability")
ax.legend()
ax.set_xlabel("Time")
ax.set_ylabel("Occupation probability")
ax.set_title("Vacuum Rabi oscillations")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/qutip/solver/solver_base.py:576: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters
omega = 2 * np.pi
g = 0.1 * 2 * np.pi  # Coupling strength
N = 3  # Number of Fock states in the cavity
theta = 0  # Angle determining the qubit orientation
kappa = 0.00005  # Cavity dissipation rate
gamma = 0.0005  # Qubit relaxation rate
tlist = np.linspace(0, 30, 200)  # Time array for simulation
epsilon = 2 * omega * np.sin(theta)  # Energy detuning of the qubit
t_c = omega * np.cos(theta)  # Tunnel coupling between qubit states



# Initial state
psi0 = tensor(basis(N, 1), basis(2, 0))  # Qubit in the ground state

# Operators
a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity
sigma_x = tensor(qeye(N), Qobj([[0, 1], [1, 0]]))  # Pauli X
sigma_z = tensor(qeye(N), Qobj([[1, 0], [0, -1]]))  # Pauli Z
idn = tensor(qeye(N), qeye(2))  # Identity operator

# Set up ranges for omega_R
omega_R_values = np.linspace(1.5 * omega, 2.5 * omega, 100)  # Fine-grained range of omega_R values
amplitudes = []

# Loop through different omega_R values
for omega_R in omega_R_values:
    H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
    H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)
    H_res = omega_R * a.dag() * a
    H = H_matrix + H_interaction + H_res

    # Collapse operators for dissipation
    c_ops = []

    # Solve the master equation
    output = mesolve(H, psi0, tlist, c_ops, [])  # Keeps qubit excitation probability
    states = output.states  # Full states for extracting amplitudes

    # Extract the amplitude of the qubit's excited state (|1⟩)
    amplitudes.append([abs(state.ptrace(1).full()[1, 1]) for state in states])

# Convert data to a 2D array
amplitudes = np.array(amplitudes)

# Heatmap plot
plt.figure(figsize=(10, 6))
plt.imshow(
    amplitudes,
    aspect="auto",
    origin="lower",
    extent=[tlist[0], tlist[-1], omega_R_values[0] , omega_R_values[-1] ],
    cmap="hot",
)

# Labels and title
plt.colorbar(label="Amplitude (|ψ|)")
plt.xlabel("Time ($\mu$s)")
plt.ylabel("$\omega_R$ (MHz)")
plt.title("Heatmap of Amplitude vs Time and $\omega_R$")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters
omega = 2 * np.pi
g = 0.1 * 2 * np.pi  # Coupling strength
N = 3  # Number of Fock states in the cavity
kappa = 0.00005  # Cavity dissipation rate
gamma = 0.0005  # Qubit relaxation rate
tlist = np.linspace(0, 30, 200)  # Time array for simulation
omega_R = 2*omega  # Fixed omega_R value


a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity

# Range of theta values
theta_values = np.linspace(0, np.pi, 100)  # Theta varies from 0 to π
amplitudes = []

# Loop through different theta values
for theta in theta_values:
    epsilon = 2 * omega * np.sin(theta)  # Energy detuning of the qubit
    t_c = omega * np.cos(theta)  # Tunnel coupling between qubit states

    H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
    H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)
    H_res = omega_R * a.dag()*a
    H = H_matrix + H_interaction + H_res

    # Collapse operators for dissipation
    c_ops = []

    # Solve the master equation
    psi0 = tensor(basis(N, 1), basis(2, 0))  # Initial state
    output = mesolve(H, psi0, tlist, c_ops, [])
    states = output.states  # Full states for extracting amplitudes

    # Extract the amplitude of the qubit's excited state (|1⟩)
    amplitudes.append([abs(state.ptrace(1).full()[1, 1]) for state in states])

# Convert data to a 2D array
amplitudes = np.array(amplitudes)

# Heatmap Plot
plt.figure(figsize=(12, 6))
plt.imshow(
    amplitudes,
    extent=[tlist[0], tlist[-1], theta_values[0], theta_values[-1]],
    aspect="auto",
    origin="lower",
    cmap="hot",
)
plt.colorbar(label="Amplitude (|ψ|)")
plt.xlabel("Time ($\mu$s)")
plt.ylabel(r"$\theta$ (radians)")
plt.title("Amplitude Heatmap: Time vs θ (Fixed $\omega_R$)")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/qutip/solver/solver_base.py:576: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *

# Define system parameters
omega = 2 * np.pi
g = 0.1 * 2 * np.pi  # Coupling strength
N = 3  # Number of Fock states in the cavity
kappa = 0.00005  # Cavity dissipation rate
gamma = 0.0005  # Qubit relaxation rate
tlist = np.linspace(0, 100, 200)  # Time array for simulation
theta = np.pi / 4  # Fixed theta value

a = tensor(destroy(N), qeye(2))  # Cavity annihilation operator
adag = a.dag() # Creation operator for the cavity

# Range of (omega_R - omega) values
omega_diff = np.linspace(0 * omega, 2.5 * omega, 100)  # Range of (omega_R - omega)
amplitudes = []

# Loop through different omega_R - omega values
for delta in omega_diff:
    omega_R = omega + delta  # Adjusted omega_R
    epsilon = 2 * omega * np.sin(theta)  # Energy detuning of the qubit
    t_c = omega * np.cos(theta)  # Tunnel coupling between qubit states

    H_interaction = (g * (a + adag)) * (np.sin(theta) * sigma_z + np.cos(theta) * sigma_x)
    H_matrix = -(np.sqrt(((epsilon/2)**2)+t_c**2)*sigma_z)
    H_res = omega_R * a.dag()*a
    H = H_matrix + H_interaction + H_res

    # Collapse operators for dissipation
    c_ops = []

    # Solve the master equation
    psi0 = tensor(basis(N, 1), basis(2, 0))  # Initial state
    output = mesolve(H, psi0, tlist, c_ops, [])
    states = output.states  # Full states for extracting amplitudes

    # Extract the amplitude of the qubit's excited state (|1⟩)
    amplitudes.append([abs(state.ptrace(1).full()[1, 1]) for state in states])

# Convert data to a 2D array
amplitudes = np.array(amplitudes)

# Heatmap Plot
plt.figure(figsize=(12, 6))
plt.imshow(
    amplitudes,
    extent=[tlist[0], tlist[-1], omega_diff[0], omega_diff[-1]],
    aspect="auto",
    origin="lower",
    cmap="hot",
)
plt.colorbar(label="Amplitude (|ψ|)")
plt.xlabel("Time ($\mu$s)")
plt.ylabel(r"$(\omega_R - \omega)$ (rad/s)")
plt.title("Amplitude Heatmap: Time vs $(\omega_R - \omega)$ (Fixed θ)")
plt.show()
